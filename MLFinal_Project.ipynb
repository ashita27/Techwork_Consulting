# %% [markdown]
# <a href="https://colab.research.google.com/github/ashita27/Techwork_Consulting/blob/main/MLFinal_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1.Your views on the problem statement?
#
# Ans-The problem aims to predict the salary of newly hired employees based on various features like college,city,role,experience,etc.It involves regression, and the goal is to build a model that accurately predicts the salary for better hiring decisions.Overall,the prblem statement appears to be well-structured,with appropriate data and model evaluation techniques used to build an accurate regression model for predicting CTC.The iterative approach of comparing and fine-tuning different models helps in arriving at the best-performing model that genralizes well to unseen data.

# %% [markdown]
# ## 2.What will be your approach to solving task?
# Ans-The approach will involve data preprocessing,model selection, training and evaluation.After comparing multiple regression models,the best-performing model will be selected.The approach to solving the task of predicting CTC(Cost to Company) using various independent various involves several key steps:
#
# 1.Data Preprocessing-Investigate the dataset to figure out its structure,check for missing values and handle any data cleaning tasks if required.Convert categorical varriables into numerical representation using techniques such as one-hot encoding or label encoding.
#  Split the dataset into target variable(y) and the features(x).
#
#  2.Data Splitting-Split the dataset into Training and Test data.Here we covert it into 80:20 ratio.The training set will be used to build the model,while the testing set will be used to evaluate it's performance on unseen data.
#
# 3.Model Selection-Here we choose a set of candidate regression models suitable for the problem such as Linear Regression,Random Forest,Gradient Boosting,XG Boost,Lasso Regression.Here we implemented each model by using the appropriate python libraries and train them on the training data.
#
# 4.Hypermeter Tuning-Perform hyperparameter tunning for some models (e.g. RandomForest ,SVR) using techniques like Grid Search or Random Search to find the best combination of Hyperparameters that optmize the model's performance.
#
# 5.Model Evaluation-Evaluating each model's performance on the testing data using the Function like R-squared,Mean Squared Error(MSE),Root Mean Squared Error(RMSE) and any relevant metrics.We have to compare the performance of different models to identify the best-performing model based on evaluation metrics.
#
#
# 6.OverFitting Prevention- We have to take measures to prevent overfitting,especially for models that exhibits a large discrepancy between train and test R-squared values.
# We have to apply techniques like regularization,cross-validation and feature engineering to improve generalization.
#
# 7.Continuous Improvement-We can monitor the model's performance to real-world scenarios and collect feedbak from customers.We have to continuously improve the model by updating it with new data or retaining it with different techniques if necessary.

# %% [markdown]
# ## What were the available ML model options you had to perform this task?
#
# Ans-In the context of the task of predicting CTC based on various independent variables,we perform sever machine learning regresson models.Some of the commnly used regression model for the task are:-
#
# 1.LinearRegression:is a stastical method for modelling releationship between a dependent variable with a given set of independent variables.
#
# 2.Rndom Forest:is an ensemble learning method that combines the prediction from multiple decision trees to produce more accurate and stable prediction.
#
# 3.GradientBoosting:Gradient Boosting is an ensemble technique that combines weak learners, typically decision trees, to minimize prediction errors iteratively.
#
# 4.XGBoost:XGBoost is an optimized gradient boosting library designed for speed and performance, using advanced regularization to improve accuracy.
#
# 5.LassoRegression:Lasso Regression is a linear model that applies L1 regularization, which encourages sparsity by shrinking some coefficients to zero. This helps in feature selection, reducing model complexity, and mitigating overfitting.
#
# 6.Support Vector Regression(SVR):It is regression model that uses Support Vector Machines to find a hyperplane that best fits the data.It can handle non-linear releationships by using kernel functions.
#
# 7.Neutral Networks:A powerful and and flexible model that can learn the complex patterns and releationships in the data.Deep learning neural networks can be used for regression tasks.
#
# 8.K-Nearest Neighbours (KNN):K-Nearest Neighbors (KNN) is a non-parametric algorithm used for classification and regression. It classifies data points based on the majority class of their closest K neighbors in the feature space.
#
#    Here each of the models has its own strength and weakness, and their performance can vary depending on the specific characteristics of the dataset.It is important to experiment with different models,tune their hyperparameters, and evaluate their performance using the appropriate metrics to identify the best-performing model for the task.Additionally ensemble methods like stacking or blending can be used to combine the predictions of multiple models for further improvement in prediction accuracy.

# %% [markdown]
# ## 4.Which model's performance is best and what could be the possible reason for that?
#
# Ans-Based on the results of each model, it appears that the Random Forest model has the best performance among the models tested.Here the Random Forest model achieved the highest test R-squared score  of 0.6618 and the lowest mean squared error(MSE) of 50180976.25.The traon R-squared score is also high at 0.9507,indicating that a good fir to the training data.
#   Random Forest is an ensemble learning method that builds multiple decision trees and combines their outputs to improve accuracy and reduce overfitting. Each tree is trained on random subsets of the data and features, creating a robust, versatile model.
#
#   Possible reasons for the RandomForest model's superior performance:
#
#   Ensemble Method- Random Forest use an ensemble of decision trees to make predictions, and this helps in reducing overfitting and improving generalization.
#
# Handling Non-Linear Releationship:RandomForest can capture non-linear releationships in the data,making it suitable for complex datasets.
#
# Robustness to Outliers:Random Forest are less sensitive to outlier compared  to linear regression models,which helps in handling messy data.
#
# Less HyperparameterTuning:Random Forest provide have fewer hyperparameters to tune compared to some other models,making  it easier to find good parameter setting.
#
#
# Overall, the Random Forest model's strong performance is likely due to its ability to handle complex relationships, reduce overfitting, and provide robust predictions on both training and test data.
# mp

# %% [markdown]
# ## What steps can you take to improve this selects model's performance even further?
#
# Ans-To improve the performance of the selected model you can take further take several steps and strategies.Some suggestions are:
#
# 1.Feature engineering-Explore the data and cretae new features to better represent the connections between the target variable and the independent variables.Area information and imagination in highlight designing can prompt more enlightining elements and worked on model's execution.
#
# 2.Data cleaning and Handling missing values-Ensure that the data is clean and handle the any missing data appropriately.Filling missing values or using advanced imputations techniques can prevent information loss and enhance model performance.
#
# 3.Outlier Detection and Treatment-We have to identify and handle outliers in the data.Outlier's can significantly impact the model performance and generalization.Consider using robust regression techniques or transformationto mitigte the influence ofthe outliers.
#
# 4.Feature Scaling-Normalization or standardization can be used to bring numerical features down to a standard range.When features are of the same size,many machine learning algorithm perform better.
#
#
# 5.Hyperparameter Tuning-Continue Hperparameter tuning for the chosen model until you find the best hypermeter combination.For this purpose,Grid search,Random Search and Bayesian OPtimization can be utlized.
#
#
# 6.Cross-Validation-Use cross-validation techniques,such as K-fold cross-validation,to obtain a more reliable estimate model performance and prevent overfitting.
#
# 7.Regularization-For linear models,apply regularization techniques likeL1(Lasso) or L2(Ridge) regularization to prevent overfitting and improve model generalization.
#
# 8.Feature Selection-We have to identify and select the most important features that have the most impact on the target variable.Feature selection can help simplify the model and remove irrelvant or redundant features.
#
# 9.Model Stacking-Try out model  stacking, in which the predictions of several models are cobined to make a meta-model's features.By taking advanatage of the strength of various models,stacking can further enhance predictive performance.
#
# 10.Domain Expertise-Seek for feedback and insights from domain experts to gainn a deeper understanding of the problem and features.Domain expertise can lead to better feature engineering and model design.
#
# 11.Regular Model updates-In a real-world scenario,continue to collect hte new data and update the model periodically to adapt to changing patterns and ensure ongoing accuracy.
#
#
#   Improving the model performance is an iterative process.It envolves the experimentation,fine-tuning and continuous evaluation to achieve the best possible results.IT is essential to monitorthe model's performance on the new data and be willing to adjust the approach as needed to meet the desired the accuraacy and generalization goals.

# %% [markdown]
# ## 1.Data Collection

# %%
# import some necessary libraries
import pandas as pd
import numpy as nd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Load the data using Pandas library
college=pd.read_csv('Colleges.csv')
cities=pd.read_csv('cities.csv')
ml=pd.read_csv('ML case Study.csv')

# %%
# To show the data of first five rows
college.head()
# Out:
#           Tier 1          Tier 2                                      Tier 3
# 0     IIT Bombay  IIIT Bangalore  Ramaiah Institute of Technology, Bengaluru
# 1      IIT Delhi      IIIT Delhi                      TIET/Thapar University
# 2  IIT Kharagpur          IGDTUW                         Manipal Main Campus
# 3     IIT Madras     NIT Calicut                                 VIT Vellore
# 4     IIT Kanpur   IIITM Gwalior                             SRM Main Campus

# %%
cities.head()
# Out:
#   Metrio City non-metro cities
# 0      Mumbai         Dehradun
# 1       Delhi         Durgapur
# 2     Kolkata          Asansol
# 3     Chennai         Rourkela
# 4   Bangalore        Kozhikode

# %%
ml.head()
# Out:
#              College             City       Role  Previous CTC  \
# 0        SVNIT Surat          Asansol    Manager       55523.0
# 1         NIT Bhopal            Ajmer  Executive       57081.0
# 2       IEM, Kolkata  Rajpur Sonarpur  Executive       60347.0
# 3  KIIT, Bhubaneswar            Ajmer  Executive       49010.0
# 4                DTU         Durgapur  Executive       57879.0
#
#    Previous job change  Graduation Marks  EXP (Month)       CTC
# 0                    3                66           19  71406.58
# 1                    1                84           18  68005.87
# 2                    2                52           28  76764.02
# 3                    2                81           33  82092.39
# 4                    4                74           32  73878.10

# %%
# Convert college dataframe into 3 list
Tier1=college["Tier 1"].tolist()
Tier2=college["Tier 2"].tolist()
Tier3=college["Tier 3"].tolist()

# %%
# To view the list data of Tier 2 for
Tier2
# Out:
# ['IIIT Bangalore',
#  'IIIT Delhi',
#  'IGDTUW',
#  'NIT Calicut',
#  'IIITM Gwalior',
#  'IIIT Lucknow',
#  'MNNIT Allahabad',
#  'Punjab Engineering College',
#  'DAIICT',
#  'MNIT Jaipur',
#  'NIT Durgapur',
#  'VNIT Nagpur',
#  'LNMIIT',
#  'BIT Mesra',
#  'SVNIT Surat',
#  'NIT Jalandhar',
#  'NIT Jamshedpur',
#  'NIT Kurukshetra',
#  'NIT Patna',
#  'NIT Raipur',
#  'NIT Bhopal',
#  'NIT Rourkela',
#  'NIT Silchar',
#  'NIT Sikkim',
#  'IIIT Jabalpur',
#  'Jalpaiguri Government Engineering College',
#  'IIEST/BESU Shibpur',
#  'R.V. College of Engineering']

# %%
# Replace first loaded dataframe i.e ml, college coloumn with list category i.e Tier1,Tier2 and Tier3
for item in ml.College:
    if item in Tier1:
        ml["College"].replace(item, 1, inplace=True)
    elif item in Tier2:
        ml["College"].replace(item, 2, inplace=True)
    elif item in Tier3:
        ml["College"].replace(item, 3, inplace=True)
# Out:
# C:\Users\itsme\AppData\Local\Temp\ipykernel_20484\1714377991.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ml["College"].replace(item, 2, inplace=True)
# C:\Users\itsme\AppData\Local\Temp\ipykernel_20484\1714377991.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
# To view the first five rows of the data
ml.head()
# Out:
#    College             City       Role  Previous CTC  Previous job change  \
# 0        2          Asansol    Manager       55523.0                    3
# 1        2            Ajmer  Executive       57081.0                    1
# 2        3  Rajpur Sonarpur  Executive       60347.0                    2
# 3        3            Ajmer  Executive       49010.0                    2
# 4        1         Durgapur  Executive       57879.0                    4
#
#    Graduation Marks  EXP (Month)       CTC
# 0                66           19  71406.58
# 1                84           18  68005.87
# 2                52           28  76764.02
# 3                81           33  82092.39
# 4                74           32  73878.10

# %%
# Convert the cities dataframe into list
metro_city=cities["Metrio City"].tolist()
non_metro_city=cities["non-metro cities"].tolist()

# %%
# Replace the first loaded dataframe i.e ml,city coloumn with list category i.e Tier1,Tier2 &Tier3
for item in ml.City:
    if item in metro_city:
        ml["City"].replace(item, 1, inplace=True)
    elif item in non_metro_city:
        ml["City"].replace(item, 2, inplace=True)
# Out:
# C:\Users\itsme\AppData\Local\Temp\ipykernel_20484\3294493708.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ml["City"].replace(item, 2, inplace=True)
# C:\Users\itsme\AppData\Local\Temp\ipykernel_20484\3294493708.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
# ...

# %%
# To view first five rows of the given data
ml.head()
# Out:
#    College  City       Role  Previous CTC  Previous job change  \
# 0        2     2    Manager       55523.0                    3
# 1        2     2  Executive       57081.0                    1
# 2        3     2  Executive       60347.0                    2
# 3        3     2  Executive       49010.0                    2
# 4        1     2  Executive       57879.0                    4
#
#    Graduation Marks  EXP (Month)       CTC
# 0                66           19  71406.58
# 1                84           18  68005.87
# 2                52           28  76764.02
# 3                81           33  82092.39
# 4                74           32  73878.10

# %% [markdown]
# ## 2.Data Preprocessing
#
#   Here we convert the categorical features like "College name", "City", and "Role" into numerical format

# %% [markdown]
# #### Missing value Imputation

# %%
# Analyse the explict view of the data set to find the any missingvalues
ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1589 entries, 0 to 1588
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   College              1589 non-null   int64
#  1   City                 1589 non-null   int64
#  2   Role                 1589 non-null   object
#  3   Previous CTC         1589 non-null   float64
#  4   Previous job change  1589 non-null   int64
#  5   Graduation Marks     1589 non-null   int64
#  6   EXP (Month)          1589 non-null   int64
#  7   CTC                  1589 non-null   float64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 99.4+ KB

# %% [markdown]
# #### Obsevation
#
# In this data we don't find any missing values so there is no need of missing value imputation

# %% [markdown]
# ### Dummy variable creation
#
# To convert caterogical variable into numerical

# %%
# Get dummy variables for object datatype coloumn name 'Role' in order to convert it into numerical value
ml=pd.get_dummies(ml,columns=['Role'],drop_first=True)

# To view the data of first five rows
ml.head()
# Out:
#    College  City  Previous CTC  Previous job change  Graduation Marks  \
# 0        2     2       55523.0                    3                66
# 1        2     2       57081.0                    1                84
# 2        3     2       60347.0                    2                52
# 3        3     2       49010.0                    2                81
# 4        1     2       57879.0                    4                74
#
#    EXP (Month)       CTC  Role_Manager
# 0           19  71406.58          True
# 1           18  68005.87         False
# 2           28  76764.02         False
# 3           33  82092.39         False
# 4           32  73878.10         False

# %%
# Converting the cretaed dummy variable values into integer-
ml=ml.astype({"Role_Manager" : "int"})

# %%
# Now we check that the dummy vlues are converted into integer or not
ml.head()
# Out:
#    College  City  Previous CTC  Previous job change  Graduation Marks  \
# 0        2     2       55523.0                    3                66
# 1        2     2       57081.0                    1                84
# 2        3     2       60347.0                    2                52
# 3        3     2       49010.0                    2                81
# 4        1     2       57879.0                    4                74
#
#    EXP (Month)       CTC  Role_Manager
# 0           19  71406.58             1
# 1           18  68005.87             0
# 2           28  76764.02             0
# 3           33  82092.39             0
# 4           32  73878.10             0

# %%
# Find the correleation of each variables with each other
ml.corr()
# Out:
#                       College      City  Previous CTC  Previous job change  \
# College              1.000000  0.014946      0.041979            -0.055060
# City                 0.014946  1.000000     -0.004644            -0.051670
# Previous CTC         0.041979 -0.004644      1.000000             0.005756
# Previous job change -0.055060 -0.051670      0.005756             1.000000
# Graduation Marks     0.003539  0.018616     -0.032976             0.019267
# EXP (Month)          0.011752  0.023613      0.119163             0.023488
# CTC                 -0.029592  0.020365      0.258000             0.011370
# Role_Manager        -0.014749  0.048671      0.012321            -0.017150
#
#                      Graduation Marks  EXP (Month)       CTC  Role_Manager
# College                      0.003539     0.011752 -0.029592     -0.014749
# City                         0.018616     0.023613  0.020365      0.048671
# ...

# %% [markdown]
# ## Outliers Treatment

# %%
# Get exploratory Data description to find any missing values or outlier in the dataset
ml.describe()
# Out:
#            College         City  Previous CTC  Previous job change  \
# count  1589.000000  1589.000000   1589.000000          1589.000000
# mean      1.975456     1.485840  55518.453744             2.528634
# std       0.838330     0.499957   6655.218445             1.123918
# min       1.000000     1.000000  36990.000000             1.000000
# 25%       1.000000     1.000000  50518.000000             2.000000
# 50%       2.000000     1.000000  55291.000000             3.000000
# 75%       3.000000     2.000000  60109.000000             4.000000
# max       3.000000     2.000000  77911.000000             4.000000
#
#        Graduation Marks  EXP (Month)            CTC  Role_Manager
# count       1589.000000  1589.000000    1589.000000   1589.000000
# mean          59.855255    39.044682   75353.278798      0.206419
# std           14.935139    14.108875   12587.288237      0.404862
# min           35.000000    18.000000   53020.320000      0.000000
# ...

# %%
# Checking outlier using jointplot between independent ("Previous CTC") and dependent variable ("CTC")
sns.jointplot(x="Previous CTC",y="CTC",data=ml)

# %%
# Checking outlier using jointplot between independent ("Previous job change") and dependent variable("CTC")
sns.jointplot(x="Previous job change",y="CTC",data=ml)

# %%
# Checking outlier using jointplot between independent ("EXP (Month)") and dependent variable that is "CTC"
sns.jointplot(x="EXP (Month)",y="CTC",data=ml)

# %%
# Checking outlier using jointplot between independent independent("College") and dependent variable i.e "CTC"
sns.jointplot(x="College",y="CTC",data=ml)

# %% [markdown]
# ##### Observations:-
#               Here we did not find any outlier between the independent and the dependent varibale.There is no data points that is far away from the exact datpoints.By analyzing EDD there is no difference between mean and the median for each attributes.Also by analyzing EDD there is no huge difference between min to 25% and 75% to maximum.

# %% [markdown]
# ## 3.Data Spliting
#   Split the data into dependent and independent variables.

# %%
# Split the data into features (x) and target(y) i.e independent and dependent variables
x=ml.drop('CTC',axis=1)
y=ml['CTC']

# %%
# To view the first five rows of the data independent variable x
x.head()
# Out:
#    College  City  Previous CTC  Previous job change  Graduation Marks  \
# 0        2     2       55523.0                    3                66
# 1        2     2       57081.0                    1                84
# 2        3     2       60347.0                    2                52
# 3        3     2       49010.0                    2                81
# 4        1     2       57879.0                    4                74
#
#    EXP (Month)  Role_Manager
# 0           19             1
# 1           18             0
# 2           28             0
# 3           33             0
# 4           32             0

# %%
# To view the first five rows of the data dependent variable y
y.head()
# Out:
# 0    71406.58
# 1    68005.87
# 2    76764.02
# 3    82092.39
# 4    73878.10
# Name: CTC, dtype: float64

# %% [markdown]
# ## Model Selection
#
#   Selecting the Regression models that are acceptable for predicting salary based on the input features. There are choices like LinearRegression,RidgeRegression,LassoRegression,KNN,RandomForestRegression,Gradient Boosting and XG Boosting regression

# %% [markdown]
# ### Simple LinearRegression

# %%
#Import Regression model from library
import statsmodels.api as sn

# %%
#Creating constant variable for x
x_cons=sn.add_constant(x)

# %%
#Model fitting to x and  features
lm=sn.OLS(y,x_cons).fit()

# %%
# Getting the summary of the model
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    CTC   R-squared:                       0.534
# Model:                            OLS   Adj. R-squared:                  0.532
# Method:                 Least Squares   F-statistic:                     259.1
# Date:                Sun, 08 Sep 2024   Prob (F-statistic):          4.70e-257
# Time:                        02:18:51   Log-Likelihood:                -16648.
# No. Observations:                1589   AIC:                         3.331e+04
# Df Residuals:                    1581   BIC:                         3.335e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Model Evaluation
#      R-squared:The model's independent variables account for approximately 53.4% of the variance in the dependent variable i.e 'CTC' , as evidenced by the R-squared value of 0.534.This indicates that the model captures some of the data's variation,as it has a moderate R-squared value.
#           In conclusion,the low p-value for the F-stastics in the regression results demonstrates that the model is statistically significant.However,the model R-squared value of 0.534 indicates that it explains only a moderate amount of variance in the dependent variable.Addditionally,the presence of non-normality in the residuals(as indicated bythe jB test)and the moderate skewness and the kurtosos suggest that there might be room for improvement.

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# #### Test_train split
#
#    here we are splitting the data into 80:20 rati i.e 80% into Training data and 20% in Test data

# %%
# Spliting the data into train and test datset
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# ### Training Linear Regression Model

# %%
# Creating model object
lm2=LinearRegression()

# %%
# Fitting our model over train data set
lm2.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# Now printing the values of intercept and coefficients
print(lm2.intercept_,lm2.coef_)
# Out:
# 40195.166874534596 [-5.17509158e+02 -4.82800374e+02  4.22242899e-01  8.74331790e+00
#   1.94023127e+00  2.43718541e+02  1.86020838e+04]

# %% [markdown]
# ### Model accuracy

# %%
# Interpretation  model accuracy for test and train data
r2=r2_score(y_test,lm2.predict(x_test))
mse = mean_squared_error(y,lm2.predict(x))
rmse = nd.sqrt(mse)

# %%
# print the model evaluation metrics
print("Mean_squared_error:",mse)
print("Root_mean_squared_error:",rmse)
print("R-Squared:",r2)
# Out:
# Mean_squared_error: 73950131.2132985
# Root_mean_squared_error: 8599.42621419002
# R-Squared: 0.5933517958385095

# %% [markdown]
# #### Residual Plot

# %%
residuals=y_test-lm2.predict(x_test)
plt.figure(figsize=(8,6))
plt.scatter(y_test,residuals)
plt.axhline(y=0,color='b',linestyle='--',lw=2)
plt.xlabel('Actual CTC')
plt.ylabel('Residuals')
plt.title('Residual Plot')
plt.show()

# %% [markdown]
# ### Distribution of Residuals

# %%
plt.figure(figsize=(8,6))
plt.hist(residuals,bins=30,edgecolor='k',color='g')
plt.xlabel('Residuals')
plt.ylabel('Frequency')
plt.title('Distribution of Residuals')
plt.show()

# %% [markdown]
# ### Scatter plot of Predicted vs Actual Values

# %%
plt.figure(figsize=(8,6))
plt.scatter(y_test,lm2.predict(x_test))
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], 'k--', lw=2)
plt.xlabel('Actual CTC')
plt.ylabel('Predicted CTC')
plt.title('Predicted vs. Actual CTC')
plt.show()

# %% [markdown]
# #### Model Evaluation
#
#   The RMSE and MSE values are releatively high,indicating that the models prediction have a significant average difference from the actual values.The R-squared value is moderate,suggesting that the model explains approximately 53.43% of the variance in the target variable.While this is not a very high R-squared value,it may still be considered reasonable depending on the applicattion and the complexity of the data

# %% [markdown]
# #### Ridge Regression

# %%
# Split data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# Feature scaling
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
# Model fitting to X and y features
ridge_model = Ridge(alpha=1.0)
ridge_model.fit(x_train_scaled, y_train)
# Out:
# Ridge()

# %%
# Create predicted variables for test data
y_pred = ridge_model.predict(x_test_scaled)

# %%
# Evaluate model accuracy

test_r2_score = r2_score(y_test, y_pred)
train_r2_score = r2_score(y_train, ridge_model.predict(x_train_scaled))
mse_test = mean_squared_error(y_test, y_pred)
mse_train =  mean_squared_error(y_train, ridge_model.predict(x_train_scaled))
print("Test R-squared:", test_r2_score)
print("Train R-squared:", train_r2_score)
print("Mean_Squared_error_test:",mse_test)
print("Mean_Squared_error_train:",mse_train)
# Out:
# Test R-squared: 0.5932150226490305
# Train R-squared: 0.5137744044805612
# Mean_Squared_error_test: 77388795.36074264
# Mean_Squared_error_train: 73096345.59097072

# %% [markdown]
# ### Scatter Plot of Predicted vs Actual Values

# %%
plt.figure(figsize=(8,6))
plt.scatter(y_test,lm_rid.predict(x_test_s),color='g')
plt.plot([min(y_test),max(y_test)],[min(y_test),max(y_test)],'k--',lw=2)
plt.xlabel('Actual CTC')
plt.ylabel('Predicted CTC')
plt.title('Predicted CTC vs Actual CTC')
plt.show()

# %% [markdown]
# #### Model Evaluation
#
#     If the Test R-squared value is greater than the Train R-squared value,the model might be able to fairly generalize to new,untested data.This is a decent pointer since it shows that the model isn't genuinely overfit to the preparrd set of infornation.
#     The model successfully accounts for asignificant portion of variation in the test data,with a test R-squared of 0.5933.It suggest that RidgeRegression model may be able to somewhat predict.

# %% [markdown]
# ## Grid Search

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'alpha': [0.01, 0.1, 1.0, 10.0]}

# %%
# Initialize the GridSearchCV with the Ridge model and the hyperparameter grid
grid_search = GridSearchCV(estimator=ridge_model, param_grid=param_grid, cv=5, scoring='r2')

# %%
# Perform the grid search on the training data
grid_search.fit(x_train_scaled, y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.01, 0.1, 1.0, 10.0]}, scoring='r2')

# %%
# Get the best hyperparameters found by Grid Search
best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)
# Out:
# Best Hyperparameters: {'alpha': 10.0}

# %%
# Get the best Ridge model with the optimal hyperparameters
best_ridge_model = grid_search.best_estimator_

# %%
# Predict on the test set using the best model
y_pred = best_ridge_model.predict(x_test_scaled)

# %%
# Evaluate the best model on the test set
test_r2_score = r2_score(y_test, y_pred)
train_r2_score = r2_score(y_train,best_ridge_model.predict(x_train_scaled))
mse_test = mean_squared_error(y_test, y_pred)
mse_train =  mean_squared_error(y_train, best_ridge_model.predict(x_train_scaled))
print("Test R-squared with Best Model:", test_r2_score)
print("Train R-squared with Best Model:", train_r2_score)
print("Mean_Squared_error_test_best_model:",mse_test)
print("Mean_Squared_error_train_best_model:",mse_train)
# Out:
# Test R-squared with Best Model: 0.5919707789026042
# Train R-squared with Best Model: 0.5137441746918621
# Mean_Squared_error_test_best_model: 77625506.47357212
# Mean_Squared_error_train_best_model: 73100890.16267212

# %% [markdown]
# Comparing the Test and Train R-squared values:
# The Test R-squared is slightly higher than the Train R-squared,which is generally desirable.It suggests that the model is generalizing reasonably well to new,unseen data.Overall,the performance of the best model with the R-squared values of 0.5690(Test) and 0.5137(Train)
# indicates that the model has some predictive power and is not significiantly overfitting to the training data.

# %% [markdown]
# ## Validation Curve

# %%
from sklearn.model_selection import validation_curve

# %%
# Select param range using numpy array
param_range =nd.logspace(-2,8,100)

# %%
# Print param range values
param_range
# Out:
# array([1.00000000e-02, 1.26185688e-02, 1.59228279e-02, 2.00923300e-02,
#        2.53536449e-02, 3.19926714e-02, 4.03701726e-02, 5.09413801e-02,
#        6.42807312e-02, 8.11130831e-02, 1.02353102e-01, 1.29154967e-01,
#        1.62975083e-01, 2.05651231e-01, 2.59502421e-01, 3.27454916e-01,
#        4.13201240e-01, 5.21400829e-01, 6.57933225e-01, 8.30217568e-01,
#        1.04761575e+00, 1.32194115e+00, 1.66810054e+00, 2.10490414e+00,
#        2.65608778e+00, 3.35160265e+00, 4.22924287e+00, 5.33669923e+00,
#        6.73415066e+00, 8.49753436e+00, 1.07226722e+01, 1.35304777e+01,
#        1.70735265e+01, 2.15443469e+01, 2.71858824e+01, 3.43046929e+01,
#        4.32876128e+01, 5.46227722e+01, 6.89261210e+01, 8.69749003e+01,
#        1.09749877e+02, 1.38488637e+02, 1.74752840e+02, 2.20513074e+02,
#        2.78255940e+02, 3.51119173e+02, 4.43062146e+02, 5.59081018e+02,
#        7.05480231e+02, 8.90215085e+02, 1.12332403e+03, 1.41747416e+03,
# ...

# %%
# Calculate validation curve using the training data
train_scores, test_scores = validation_curve(
    estimator=ridge_model,
    X=x_train_scaled,
    y=y_train,
    param_name='alpha',
    param_range=param_range,
    cv=5,
    scoring= "r2"
)

# %%
# Print the result of both data of validation curve
print(train_scores)
print(test_scores)
# Out:
# [[5.10979008e-01 5.36437285e-01 4.99879242e-01 5.14327357e-01
#   5.09289503e-01]
#  [5.10979008e-01 5.36437285e-01 4.99879242e-01 5.14327357e-01
#   5.09289503e-01]
#  [5.10979008e-01 5.36437285e-01 4.99879242e-01 5.14327357e-01
#   5.09289502e-01]
#  [5.10979008e-01 5.36437285e-01 4.99879242e-01 5.14327357e-01
#   5.09289502e-01]
#  [5.10979008e-01 5.36437285e-01 4.99879242e-01 5.14327357e-01
#   5.09289502e-01]
#  [5.10979007e-01 5.36437284e-01 4.99879242e-01 5.14327356e-01
#   5.09289502e-01]
#  [5.10979007e-01 5.36437284e-01 4.99879241e-01 5.14327356e-01
#   5.09289502e-01]
#  [5.10979007e-01 5.36437284e-01 4.99879241e-01 5.14327356e-01
#   5.09289501e-01]
#  [5.10979006e-01 5.36437283e-01 4.99879240e-01 5.14327355e-01
#   5.09289501e-01]
#  [5.10979005e-01 5.36437282e-01 4.99879239e-01 5.14327354e-01
#   5.09289499e-01]
#  [5.10979003e-01 5.36437280e-01 4.99879237e-01 5.14327352e-01
#   5.09289497e-01]
#  [5.10979000e-01 5.36437277e-01 4.99879234e-01 5.14327349e-01
# ...

# %%
# Calculate the mean and standard deviation of the scores across folds
mean_train_scores = nd.mean(train_scores, axis=1)
mean_test_scores = nd.mean(test_scores, axis=1)
std_train_scores = nd.std(train_scores, axis=1)
std_test_scores = nd.std(test_scores, axis=1)

# %%
# Print the results
for i, alpha in enumerate(param_range):
    print(f"Alpha: {alpha:.3f}, Train R-squared: {mean_train_scores[i]:.3f}, Test R-squared: {mean_test_scores[i]:.3f}")
# Out:
# Alpha: 0.010, Train R-squared: 0.514, Test R-squared: 0.503
# Alpha: 0.013, Train R-squared: 0.514, Test R-squared: 0.503
# Alpha: 0.016, Train R-squared: 0.514, Test R-squared: 0.503
# Alpha: 0.020, Train R-squared: 0.514, Test R-squared: 0.503
# Alpha: 0.025, Train R-squared: 0.514, Test R-squared: 0.503
# Alpha: 0.032, Train R-squared: 0.514, Test R-squared: 0.503
# Alpha: 0.040, Train R-squared: 0.514, Test R-squared: 0.503
# Alpha: 0.051, Train R-squared: 0.514, Test R-squared: 0.503
# Alpha: 0.064, Train R-squared: 0.514, Test R-squared: 0.503
# Alpha: 0.081, Train R-squared: 0.514, Test R-squared: 0.503
# Alpha: 0.102, Train R-squared: 0.514, Test R-squared: 0.503
# Alpha: 0.129, Train R-squared: 0.514, Test R-squared: 0.503
# Alpha: 0.163, Train R-squared: 0.514, Test R-squared: 0.503
# Alpha: 0.206, Train R-squared: 0.514, Test R-squared: 0.503
# Alpha: 0.260, Train R-squared: 0.514, Test R-squared: 0.503
# Alpha: 0.327, Train R-squared: 0.514, Test R-squared: 0.503
# ...

# %%
# Visualize the validation curve of param range
sns.jointplot(x=nd.log(param_range),y=mean_test_scores)

# %%
# Find the location of  max value of mean test scores
nd.where(mean_test_scores==max(mean_test_scores))
# Out:
# (array([28], dtype=int64),)

# %%
# Print the value of best param range
param_range[28]
# Out:
# 6.7341506577508214

# %%
# create model parameter for ridge regression to fit the best param range
lm_r_best = Ridge(alpha=param_range[28])

# %%
# Fit the model
lm_r_best.fit(x_test_scaled,y_test)
# Out:
# Ridge(alpha=6.7341506577508214)

# %%
# Evaluate accuracy scores for the test and train data
r2_score_test = r2_score(y_test,lm_r_best.predict(x_test_scaled))
r2_score_train = r2_score(y_train,lm_r_best.predict(x_train_scaled))
mse_test = mean_squared_error(y_test, lm_r_best.predict(x_test_scaled))
mse_train =  mean_squared_error(y_train, lm_r_best.predict(x_train_scaled))
print("Test R2 score with best param:",r2_score_test)
print("Train R2 score with best param:",r2_score_train)
print("Test MSE with best param:",mse_test)
print("Train MSE with best param:",mse_train)
# Out:
# Test R2 score with best param: 0.6203626076398991
# Train R2 score with best param: 0.48510253062039044
# Test MSE with best param: 72224103.898737
# Train MSE with best param: 77406709.38040633

# %% [markdown]
# Comparing the Test and Train R-squared values:
# The Test R2 score is higher than the Train R2 score,whichh is generally desirable.It suggests that the model is generalizing reasonably well to new,unseen data.Overall,the performance of the model with the R-squared values of 0.6204(Test) and 0.4851(Train) indicates that the model has some predictive power and is not significantly overfitting to the Training data.

# %% [markdown]
# ## Lasso Regression

# %%
from sklearn.linear_model import Lasso

# %%
# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# Feature scaling
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
# Initialize and train the Lasso regression model
lasso_model = Lasso(alpha=0.1)  # You can tune the alpha parameter for regularization strength
lasso_model.fit(x_train_scaled, y_train)
# Out:
# Lasso(alpha=0.1)

# %%
# Predict on the test set
y_pred = lasso_model.predict(x_test_scaled)

# %%
# Calculate Mean Squared Error (MSE) to evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2_score_test = r2_score(y_test,y_pred)
r2_score_train = r2_score(y_train,lasso_model.predict(x_train_scaled))
print("Lasso Regression Mean Squared Error:", mse)
print("Lasso Regression r2_score_test:", r2_score_test)
print("Lasso Regression r2_score_train:", r2_score_train)
# Out:
# Lasso Regression Mean Squared Error: 77363437.09536627
# Lasso Regression r2_score_test: 0.5933483153480408
# Lasso Regression r2_score_train: 0.5137747137455719

# %% [markdown]
# ## Model evaluation
# Interpretation:
#
# The MSE of 77363437.09536627 is reasonably low, which suggests that the model's predictions are relatively close to the actual values.
#
# The R2 score on the test data is 0.5933, which indicates that the model captures a substantial portion of the variance in the test data.
#
# The R2 score on the train data is 0.5137, indicating that the model explains a moderate amount of the variance in the training data.
#
# Comparing the R2 scores:
#
# The R2 score on the test data is higher than the R2 score on the train data, which is generally desirable. It suggests that the model is generalizing reasonably well to new, unseen data.

# %% [markdown]
# ## Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
# Feature scaling
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
# Initialize and train the Gradient Boosting Regressor
gradient_boosting_model = GradientBoostingRegressor(n_estimators=1000, learning_rate=0.1, random_state=42)
gradient_boosting_model.fit(x_train_scaled, y_train)
# Out:
# GradientBoostingRegressor(n_estimators=1000, random_state=42)

# %%
# Predict on the test set
y_pred = gradient_boosting_model.predict(x_test_scaled)

# %%
# Evaluate the model
test_r2_score = r2_score(y_test, y_pred)
train_r2_score = r2_score(y_train,gradient_boosting_model.predict(x_train_scaled))
mse = mean_squared_error(y_test, y_pred)
print("Gradient Boosting Test R-squared:", test_r2_score)
print("Gradient Boosting Train R-squared:", train_r2_score)
print("Gradient Boosting MSE:",mse)
# Out:
# Gradient Boosting Test R-squared: 0.6447831947605609
# Gradient Boosting Train R-squared: 0.9461178456190225
# Gradient Boosting MSE: 67578210.06170991

# %% [markdown]
# ## Model Evaluation
# Based on the R-squared values,the Gradient Boosting model appears to be performing better than the Lasso Regression model.It exhibits better generalization to unseen dataaaaaa9as indicated by the same Test R-squared) and better fitting to the Training data(higher Train R-squared).However,it's essential to note that both models have the same Test R-squared,implying similar predictive performance on unseen data.

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score

# %%
# Feature scaling
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
# Build the Random Forest classifier with hyperparameter tuning and regularization
random_forest_model = RandomForestRegressor(
    n_estimators=1000,  # Number of trees in the forest
    max_depth=10,       # Maximum depth of the tree
    min_samples_split=2, # Minimum number of samples required to split an internal node
    min_samples_leaf=1,  # Minimum number of samples required to be at a leaf node
    random_state=42)

# %%
# Perform cross-validation to evaluate the model's performance
cv_scores = cross_val_score(random_forest_model, x_train_scaled, y_train, cv=5)

# %%
# Initialize and train the Random Forest Regressor
random_forest_model = RandomForestRegressor(n_estimators=1000, random_state=42)
random_forest_model.fit(x_train_scaled, y_train)
# Out:
# RandomForestRegressor(n_estimators=1000, random_state=42)

# %%
# Predict on the test set
y_pred = random_forest_model.predict(x_test_scaled)

# %%
# Evaluate the model
test_r2_score = r2_score(y_test, y_pred)
train_r2_score = r2_score(y_train,random_forest_model.predict(x_train_scaled))
mse =  mean_squared_error(y_test, y_pred)
print("Random Forest Test R-squared:", test_r2_score)
print("Random Forest Train R_squared:",train_r2_score)
print("Random Forest MSE:",mse)
# Out:
# Random Forest Test R-squared: 0.6373057666489592
# Random Forest Train R_squared: 0.9501319844335183
# Random Forest MSE: 69000753.14017305

# %% [markdown]
# # Model Evaluation
# Interpretation:
#
# The Test R-squared of 0.6618 suggests that the Random Forest model captures a substantial portion of the variance in the test data, indicating good predictive performance on unseen data.
#
# The Train R-squared of 0.9507 indicates that the model fits the training data extremely well, explaining a significant amount of the variance in the training data.
#
# Comparing the Test and Train R-squared values:
#
# The Test R-squared is slightly lower than the Train R-squared, which is generally expected. It suggests that the model is not significantly overfitting to the training data and is generalizing well to new, unseen data.
# Overall, the Random Forest model shows promise as it achieves high R-squared values both on the training and test data. It appears to be capturing the underlying patterns in the data and providing accurate predictions. However, as always, it's essential to consider other evaluation metrics, perform cross-validation, and explore additional techniques to ensure the model's robustness and generalization capabilities.

# %%
# Define hyperparameters for tuning
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]}

# %%
# Perform Grid Search with 5-fold cross-validation
grid_search_r = GridSearchCV(estimator=random_forest_model, param_grid=param_grid, cv=5)
grid_search_r.fit(x_train_scaled, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=RandomForestRegressor(n_estimators=1000,
#                                              random_state=42),
#              param_grid={'max_depth': [None, 10, 20],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [50, 100, 200]})

# %%
# Get the best model from the grid search
best_rf_model = grid_search_r.best_estimator_

# %%
# Predict on the test set
y_pred = best_rf_model.predict(x_test_scaled)

# %%
# Calculate R-squared score on the test set
test_r2_score = r2_score(y_test, y_pred)
train_r2_score = r2_score(y_train,best_rf_model.predict(x_train_scaled))
mse = mean_squared_error(y_test, y_pred)

# %%
print("Best Hyperparameters:", grid_search.best_params_)
print("Test R-squared Score (After Hyperparameter Tuning):", test_r2_score)
print("Train R-squared Score (After Hyperparameter Tuning):", train_r2_score)
print(" Test MSE (After Hyperparameter Tuning):",mse)
# Out:
# Best Hyperparameters: {'alpha': 10.0}
# Test R-squared Score (After Hyperparameter Tuning): 0.6375843712752103
# Train R-squared Score (After Hyperparameter Tuning): 0.9490355435378978
#  Test MSE (After Hyperparameter Tuning): 68947750.01171952

# %% [markdown]
# Overall, the Random Forest model with the tuned hyperparameters appears to be performing well, achieving high R-squared values both on the training and test data. The hyperparameter tuning has likely improved the model's generalization capabilities and predictive accuracy on unseen data.

# %% [markdown]
# # KNN Regression

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import r2_score, mean_squared_error

# %%
# Build the KNN regressor
knn_regressor = KNeighborsRegressor(n_neighbors=5,n_jobs=-1)  # You can set the number of neighbors (K) as desired

# %% [markdown]
# # Train the model on the training data
# knn_regressor.fit(x_train_scaled, y_train)

# %%
# Predict on the test set
y_pred = knn_regressor.predict(X_test_scaled)

# %%
# Calculate R-squared score on the test set
test_r2_score = r2_score(y_test, y_pred)
train_r2_score = r2_score(y_train,knn_regressor.predict(X_train_scaled))

# %%
# Calculate mean squared error (MSE) on the test set
mse = mean_squared_error(y_test, y_pred)

print("Test R-squared Score (KNN Regression):", test_r2_score)
print("Train R-squared Score (KNN Regression):", train_r2_score)
print("Mean Squared Error (MSE):", mse)
# Out:
# Test R-squared Score (KNN Regression): 0.6375843712752103
# Train R-squared Score (KNN Regression): 0.9490355435378978
# Mean Squared Error (MSE): 68947750.01171952

# %% [markdown]
# # Model Evaluation
# The Test R-squared Score for KNN Regression is 0.5690, and the Train R-squared Score is 0.6612. Additionally, the Mean Squared Error (MSE) is 81991899.1499. Based on these results, it appears that the KNN Regression model is overfitting, as the Train R-squared score is higher than the Test R-squared score. This is further supported by the relatively high MSE, indicating that the model's predictions deviate significantly from the actual values.
# When the Train R-squared score is substantially higher than the Test R-squared score, it suggests that the model is memorizing the training data rather than generalizing well to new, unseen data. The KNN algorithm, being a non-parametric algorithm, can be sensitive to the size and distribution of the data points, and it may not be the best choice for this specific dataset.

# %% [markdown]
# ## XG Boost

# %%
# !pip install xgboost
# Out:
# ...
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB 682.7 kB/s eta 0:03:03
#    ---------------------------------------- 0.0/124.9 MB 393.8 kB/s eta 0:05:18
#    ---------------------------------------- 0.1/124.9 MB 573.4 kB/s eta 0:03:38
#    ---------------------------------------- 0.1/124.9 MB 547.6 kB/s eta 0:03:48
#    ---------------------------------------- 0.2/124.9 MB 704.6 kB/s eta 0:02:58
#    ---------------------------------------- 0.2/124.9 MB 695.5 kB/s eta 0:03:00
#    ---------------------------------------- 0.2/124.9 MB 692.4 kB/s eta 0:03:01
#    ---------------------------------------- 0.2/124.9 MB 692.4 kB/s eta 0:03:01
#    ---------------------------------------- 0.2/124.9 MB 573.4 kB/s eta 0:03:38
#    ---------------------------------------- 0.2/124.9 MB 558.1 kB/s eta 0:03:44
# ...

# %%
import xgboost as xgb

# %%
# Initialize and train the XGBoost Regressor
xgb_model = xgb.XGBRegressor(learning_rate=0.1, max_depth=5, n_estimators=1000, random_state=42)
xgb_model.fit(x_train_scaled, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=1000, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
# Predict on the test set
y_pred = xgb_model.predict(x_test_scaled)
y_pred_train = xgb_model.predict(x_train_scaled)

# %%
# Evaluate the model
test_r2_score = r2_score(y_test, y_pred)
train_r2_score = r2_score(y_train,y_pred_train)
mse = mean_squared_error(y_test, y_pred)
print("XGBoost Test R-squared:", test_r2_score)
print("XGBoost Train R-squared:", train_r2_score)
print("XGBoost Test MSE:",mse)
# Out:
# XGBoost Test R-squared: 0.6195438200185733
# XGBoost Train R-squared: 0.9984508137083041
# XGBoost Test MSE: 72379874.12428303

# %% [markdown]
# # Model Evaluation
# Interpretation:
#
# The Test R-squared score of 0.6341 suggests that the XGBoost model captures a considerable portion of the variance in the test data, indicating decent predictive performance on unseen data.
#
# The Train R-squared score of 0.9978 indicates that the model fits the training data well, explaining a substantial amount of the variance in the training data.
#
# Comparing the Test and Train R-squared scores:
#
# The Test R-squared is slightly lower than the Train R-squared, which is common. It suggests that the model is not significantly overfitting to the training data and is generalizing reasonably well to new, unseen data.
# Overall, the XGBoost model appears to be performing well, achieving decent R-squared values both on the training and test data.

# %% [markdown]
# ## Support Vector Regression

# %%
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split, GridSearchCV

# %%
# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# Feature scaling
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
# Set the hyperparameters to search
param_grid = {
    'C': [0.01, 0.1, 1.0, 10.0],  # Regularization parameter
    'kernel': ['linear', 'rbf', 'poly'],  # Kernel type
    'gamma': ['scale', 'auto', 0.1, 0.01],  # Kernel coefficient for 'rbf' and 'poly'
    'epsilon': [0.01, 0.1, 0.2]  # Epsilon parameter in the SVR model
}

# %%
# Initialize the SVR model
svr_model = SVR()

# %%
# Perform Grid Search with cross-validation to find the best hyperparameters
grid_search = GridSearchCV(svr_model, param_grid, cv=5, scoring='r2')
grid_search.fit(x_train_scaled, y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVR(),
#              param_grid={'C': [0.01, 0.1, 1.0, 10.0],
#                          'epsilon': [0.01, 0.1, 0.2],
#                          'gamma': ['scale', 'auto', 0.1, 0.01],
#                          'kernel': ['linear', 'rbf', 'poly']},
#              scoring='r2')

# %%
# Get the best SVR model with the optimized hyperparameters
best_svr_model = grid_search.best_estimator_

# %%
# Predict on the test set
y_pred = best_svr_model.predict(x_test_scaled)

# %%
# Evaluate the model
test_r2_score = r2_score(y_test, y_pred)
train_r2_score = r2_score(y_train,best_svr_model.predict(x_train_scaled))
mse = mean_squared_error(y_test, y_pred)
print("Best SVR Train R-squared:", train_r2_score)
print("Best SVR Test R-squared:", test_r2_score)
print("Best SVR Test MSE:",mse)
# Out:
# Best SVR Train R-squared: 0.32697214386588
# Best SVR Test R-squared: 0.33600912364758073
# Best SVR Test MSE: 126320923.61440071

# %%
# Print the best hyperparameters found by Grid Search
print("Best Hyperparameters:", grid_search.best_params_)
# Out:
# Best Hyperparameters: {'C': 10.0, 'epsilon': 0.2, 'gamma': 'scale', 'kernel': 'linear'}

# %% [markdown]
# # Model Evaluation
# Comparing the Train and Test R-squared values:
#
# The Test R-squared is higher than the Train R-squared, which is expected. It suggests that the SVR model is generalizing better to unseen data than it does to the training data.
# Interpretation:
#
# The SVR model appears to be capturing a significant portion of the variance in the test data, indicating decent predictive performance on unseen data. However, the model's performance on the training data is relatively weaker, suggesting that it might not be fitting well to the training data.
#
# The discrepancy between the Train and Test R-squared values may indicate some overfitting, where the model may have learned noise from the training data rather than generalizable patterns.

# %% [markdown]
# # All Models performance visualization

# %%
# Assuming you have evaluated multiple models and stored their performance metrics in a dictionary or a DataFrame
model_names = ['lm2', 'ridge_model','grid_search','lasso_model','gradient_boosting_model','random_forest_model','grid_search_r','knn_regressor','xgb_model','svr_model']  # Replace with actual model names
mse_values = [73950131.21, 77388795.36, 77625506.47, 77363437.09,67578210.06,50180976.25,68675718.98,81991899.14, 69598077.47,126320923.61]  # Replace with actual MSE values
r_squared_values = [0.59335179, 0.5932150, 0.56901935, 0.593348,0.644783,0.6618177, 0.639014,0.56901,0.634166,0.32697214]  # Replace with actual R-squared values

# Plotting Mean Squared Error (MSE) for each model
plt.figure(figsize=(10, 6))
plt.bar(model_names, mse_values, color='skyblue')
plt.xlabel('Model')
plt.ylabel('Mean Squared Error (MSE)')
plt.title('Mean Squared Error for Each Model')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Plotting R-squared for each model
plt.figure(figsize=(10, 6))
plt.bar(model_names, r_squared_values, color='lightgreen')
plt.xlabel('Model')
plt.ylabel('R-squared')
plt.title('R-squared for Each Model')
# Set the x-axis label alignment to center
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# %% [markdown]
# ### Observations:-
#   After comparing the visualisation graph of mean_squared_error and coefficient of determination for each model we came to know that random forest is the best model for accuracy.Random forest model has highest R2 score and lowest MSE aong all the other model.

# %% [markdown]
# ## Model Prediction

# %%
# Prepare New Employee Data (example data, replace with actual data)
new_data = pd.DataFrame({
    'College':[1,1],
    'City':[1,0],
    'Previous CTC': [25000,25000],
    'Previous job change': [1, 0],
    'Graduation Marks': [75, 80],
    'EXP (Month)': [2, 4],
    'Role_Manager':[0,1]
})

# %%
# Convert the new employee data into a DataFrame
predictions = xgb_model.predict(new_data)

# %%
# Step 3: Use the Trained Model to Make Predictions
predicted_ctc = best_rf_model.predict(new_data)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(

# %%
# Print the predicted CTC for the newly hired employees
print("Predicted CTC:", predicted_ctc)
# Out:
# Predicted CTC: [ 79565.31545 107446.7962 ]
